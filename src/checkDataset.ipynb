# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# constants
c = [-3.4514602950238413, 1.5113482974975188, 0.04506911694138332, 0.08481774081897564, -0.09929570045713661, -0.1052114951314593, -0.06962702815752816, 0.9220802908586258, 6.064459319103737, 0.0008315096586496537, 0.0004046852066223911, 0.0021323793348923844]

# %%
# Load Android Data
data_source = 'android_data'
data_type = 'sit'
data_num = '1'
data_url = '../data/' + data_source + '/' + data_type + '/' + data_type + '_' + data_num + '.csv'

data = pd.read_csv(data_url, sep=';')

# %%
# Load Orignal Data
data_source_o = 'dataset'
data_type_o = 'sit_5'
data_num_o = '1'
data_url_o = '../data/' + data_source_o + '/' + data_type_o + '/' + 'sub_' + data_num_o + '.csv'

data_o = pd.read_csv(data_url_o)

# %%
# drop id
data.drop('id', axis=1, inplace=True)

# %%
data_o
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.351138       -0.416302     -0.098023   0.314588
# 1               1       0.351219       -0.416372     -0.098025   0.314649
# 2               2       0.351145       -0.416497     -0.098045   0.314567
# 3               3       0.350849       -0.416695     -0.098148   0.314286
# 4               4       0.350859       -0.416863     -0.098022   0.314271
# ...           ...            ...             ...           ...        ...
# 10287       10287       0.377830       -0.366861      0.131685   0.344357
# 10288       10288       0.377431       -0.367543      0.131037   0.343920
# 10289       10289       0.376842       -0.368708      0.130356   0.343255
# 10290       10290       0.376216       -0.369163      0.129790   0.342652
# 10291       10291       0.375710       -0.369041      0.129369   0.342229
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0       0.404381  -0.858784       -0.003655        0.009577       -0.000234
# 1       0.404445  -0.858732       -0.007937        0.007457        0.000807
# 2       0.404560  -0.858708       -0.007960       -0.001053       -0.002387
# 3       0.404740  -0.858726       -0.000521       -0.006411       -0.001261
# 4       0.404894  -0.858658       -0.001613       -0.004306        0.006206
# ...          ...        ...             ...             ...             ...
# 10287   0.358687  -0.867619       -0.008201       -0.002056       -0.032352
# 10288   0.359324  -0.867528       -0.013541       -0.009469       -0.038790
# 10289   0.360411  -0.867341       -0.002946       -0.016997       -0.030162
# 10290   0.360835  -0.867403        0.021542       -0.017126       -0.019309
# 10291   0.360721  -0.867617        0.021474       -0.018246       -0.005421
#
#        userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0                0.000094            0.000252           -0.006954
# 1               -0.001309            0.002262           -0.010348
# 2               -0.002174            0.000012           -0.006664
# 3                0.001693            0.009216           -0.011575
# 4                0.005767            0.007490           -0.008926
# ...                   ...                 ...                 ...
# 10287            0.000004            0.007707           -0.003506
# 10288           -0.002688            0.006063            0.003011
# 10289            0.001548            0.019090           -0.007339
# 10290            0.004180            0.016942           -0.019789
# 10291            0.006694            0.017102           -0.014249
#
# [10292 rows x 13 columns]

# %%
data
# Out:
#         id  Attitude Roll  Attitude Pitch  Attitude Azimuth  Gravity X  \
# 0        1       0.000000        0.000000          0.000000   0.000000
# 1        2       0.000000        0.000000          0.000000   0.000000
# 2        3       0.000000        0.000000          0.000000   3.164490
# 3        4       0.000000        0.000000          0.000000   3.164490
# 4        5       0.000000        0.000000          0.000000   3.164490
# ...    ...            ...             ...               ...        ...
# 1528  1529      -0.123043       -0.265772          0.421270   3.450788
# 1529  1530      -0.123043       -0.265772          0.421270   3.450788
# 1530  1531      -0.123290       -0.265408          0.421083   3.449857
# 1531  1532      -0.123290       -0.265408          0.421083   3.449857
# 1532  1533      -0.123290       -0.265408          0.421083   3.449857
#
#       Gravity Y  Gravity Z  Rotation Rate X  Rotation Rate Y  Rotation Rate Z  \
# 0      0.000000   0.000000         0.014647         0.010386         0.003595
# 1      0.000000   0.000000         0.014647         0.010386         0.003595
# 2     -2.976691   8.791798         0.014647         0.010386         0.003595
# 3     -2.976691   8.791798         0.013981         0.004527         0.000666
# 4     -2.976691   8.791798         0.013981         0.004527         0.000666
# ...         ...        ...              ...              ...              ...
# 1528  -4.267949   8.126934        -0.003728        -0.001332         0.000533
# 1529  -4.267949   8.126934        -0.003728        -0.001332         0.000533
# 1530  -4.271181   8.125631        -0.003728        -0.001332         0.000533
# 1531  -4.271181   8.125631        -0.003728        -0.001332         0.000533
# 1532  -4.271181   8.125631         0.001997         0.001332        -0.002130
#
#       User Acceleration X  User Acceleration Z  User Acceleration Y
# 0                3.181856             8.819346            -2.981457
# 1                3.174079             8.841479            -2.968297
# 2                3.174079             8.841479            -2.968297
# 3                3.174079             8.841479            -2.968297
# 4                3.164508             8.849854            -2.886941
# ...                   ...                  ...                  ...
# 1528             3.472584             8.197810            -4.299304
# 1529             3.472584             8.197810            -4.299304
# 1530             3.485146             8.189436            -4.311268
# 1531             3.485146             8.189436            -4.311268
# 1532             3.485146             8.189436            -4.311268
#
# [1533 rows x 13 columns]

# %%
# Convert string with exponent to float64 of data2
for column in data.columns:
    if data[column].dtype == 'object':
        data[column] = data[column].apply(lambda x: float(x.lower().replace(',', '.')))

# %%
# rename Unnamed: 0 to id
data_o.rename(columns={'Unnamed: 0': 'id'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1533 entries, 0 to 1532
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1533 non-null   int64
#  1   Attitude Roll        1533 non-null   float64
#  2   Attitude Pitch       1533 non-null   float64
#  3   Attitude Azimuth     1533 non-null   float64
#  4   Gravity X            1533 non-null   float64
#  5   Gravity Y            1533 non-null   float64
#  6   Gravity Z            1533 non-null   float64
#  7   Rotation Rate X      1533 non-null   float64
#  8   Rotation Rate Y      1533 non-null   float64
#  9   Rotation Rate Z      1533 non-null   float64
#  10  User Acceleration X  1533 non-null   float64
#  11  User Acceleration Z  1533 non-null   float64
#  12  User Acceleration Y  1533 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 155.8 KB

# %%
data_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10292 entries, 0 to 10291
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  10292 non-null  int64
#  1   attitude.roll       10292 non-null  float64
#  2   attitude.pitch      10292 non-null  float64
#  3   attitude.yaw        10292 non-null  float64
#  4   gravity.x           10292 non-null  float64
#  5   gravity.y           10292 non-null  float64
#  6   gravity.z           10292 non-null  float64
#  7   rotationRate.x      10292 non-null  float64
#  8   rotationRate.y      10292 non-null  float64
#  9   rotationRate.z      10292 non-null  float64
#  10  userAcceleration.x  10292 non-null  float64
#  11  userAcceleration.y  10292 non-null  float64
#  12  userAcceleration.z  10292 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 1.0 MB

# %%
# Attitude Data
plt.figure(figsize=(20, 10))
plt.title('Attitude Data')
plt.plot(data['id'], data['Attitude Roll'], label='attitude roll')
plt.plot(data['id'], data['Attitude Pitch'], label='attitude pitch')
plt.plot(data['id'], data['Attitude Azimuth'], label='attitude azimuth')

# plot only to the length of data of android
plt.plot(data_o['id'][:len(data)], data_o['attitude.roll'][:len(data)], label='attitude roll original')
plt.plot(data_o['id'][:len(data)], data_o['attitude.pitch'][:len(data)], label='attitude pitch original')
plt.plot(data_o['id'][:len(data)], data_o['attitude.yaw'][:len(data)], label='attitude azimuth original')

plt.legend()
plt.show()

# Gravity Data
plt.figure(figsize=(20, 10))
plt.title('Gravity Data')
plt.plot(data['id'], data['Gravity X'], label='Gravity X')
plt.plot(data['id'], data['Gravity Y'], label='Gravity Y')
plt.plot(data['id'], data['Gravity Z'], label='Gravity Z')

plt.plot(data_o['id'][:len(data)], data_o['gravity.x'][:len(data)], label='gravity x original')
plt.plot(data_o['id'][:len(data)], data_o['gravity.y'][:len(data)], label='gravity y original')
plt.plot(data_o['id'][:len(data)], data_o['gravity.z'][:len(data)], label='gravity z original')

plt.legend()
plt.show()

# Rotation Data
plt.figure(figsize=(20, 10))
plt.title('Rotation Data')
plt.plot(data['id'], data['Rotation Rate X'], label='Rotation Rate X')
plt.plot(data['id'], data['Rotation Rate Y'], label='Rotation Rate Y')
plt.plot(data['id'], data['Rotation Rate Z'], label='Rotation Rate Z')

plt.plot(data_o['id'][:len(data)], data_o['rotationRate.x'][:len(data)], label='rotation rate x original')
plt.plot(data_o['id'][:len(data)], data_o['rotationRate.y'][:len(data)], label='rotation rate y original')
plt.plot(data_o['id'][:len(data)], data_o['rotationRate.z'][:len(data)], label='rotation rate z original')

plt.legend()
plt.show()

# User Acceleration Data
plt.figure(figsize=(20, 10))
plt.title('User Acceleration Data')
plt.plot(data['id'], data['User Acceleration X'], label='User Acceleration X')
plt.plot(data['id'], data['User Acceleration Y'], label='User Acceleration Y')
plt.plot(data['id'], data['User Acceleration Z'], label='User Acceleration Z')

plt.plot(data_o['id'][:len(data)], data_o['userAcceleration.x'][:len(data)], label='user acceleration x original')
plt.plot(data_o['id'][:len(data)], data_o['userAcceleration.y'][:len(data)], label='user acceleration y original')
plt.plot(data_o['id'][:len(data)], data_o['userAcceleration.z'][:len(data)], label='user acceleration z original')

plt.legend()
plt.show()

# %%
# muliply columns other than id with c
data.iloc[:, 1:] = data.iloc[:, 1:].mul(c, axis=1)

# %%
# Attitude Data
plt.figure(figsize=(20, 10))
plt.title('Attitude Data')
plt.plot(data['id'], data['Attitude Roll'], label='attitude roll')
plt.plot(data['id'], data['Attitude Pitch'], label='attitude pitch')
plt.plot(data['id'], data['Attitude Azimuth'], label='attitude azimuth')

# plot only to the length of data of android
plt.plot(data_o['id'][:len(data)], data_o['attitude.roll'][:len(data)], label='attitude roll original')
plt.plot(data_o['id'][:len(data)], data_o['attitude.pitch'][:len(data)], label='attitude pitch original')
plt.plot(data_o['id'][:len(data)], data_o['attitude.yaw'][:len(data)], label='attitude azimuth original')

plt.legend()
plt.show()

# Gravity Data
plt.figure(figsize=(20, 10))
plt.title('Gravity Data')
plt.plot(data['id'], data['Gravity X'], label='Gravity X')
plt.plot(data['id'], data['Gravity Y'], label='Gravity Y')
plt.plot(data['id'], data['Gravity Z'], label='Gravity Z')

plt.plot(data_o['id'][:len(data)], data_o['gravity.x'][:len(data)], label='gravity x original')
plt.plot(data_o['id'][:len(data)], data_o['gravity.y'][:len(data)], label='gravity y original')
plt.plot(data_o['id'][:len(data)], data_o['gravity.z'][:len(data)], label='gravity z original')

plt.legend()
plt.show()

# Rotation Data
plt.figure(figsize=(20, 10))
plt.title('Rotation Data')
plt.plot(data['id'], data['Rotation Rate X'], label='Rotation Rate X')
plt.plot(data['id'], data['Rotation Rate Y'], label='Rotation Rate Y')
plt.plot(data['id'], data['Rotation Rate Z'], label='Rotation Rate Z')

plt.plot(data_o['id'][:len(data)], data_o['rotationRate.x'][:len(data)], label='rotation rate x original')
plt.plot(data_o['id'][:len(data)], data_o['rotationRate.y'][:len(data)], label='rotation rate y original')
plt.plot(data_o['id'][:len(data)], data_o['rotationRate.z'][:len(data)], label='rotation rate z original')

plt.legend()
plt.show()

# User Acceleration Data
plt.figure(figsize=(20, 10))
plt.title('User Acceleration Data')
plt.plot(data['id'], data['User Acceleration X'], label='User Acceleration X')
plt.plot(data['id'], data['User Acceleration Y'], label='User Acceleration Y')
plt.plot(data['id'], data['User Acceleration Z'], label='User Acceleration Z')

plt.plot(data_o['id'][:len(data)], data_o['userAcceleration.x'][:len(data)], label='user acceleration x original')
plt.plot(data_o['id'][:len(data)], data_o['userAcceleration.y'][:len(data)], label='user acceleration y original')
plt.plot(data_o['id'][:len(data)], data_o['userAcceleration.z'][:len(data)], label='user acceleration z original')

plt.legend()
plt.show()

# %%
# export data1_fit to csv
data.to_csv('android_data/testing.csv', sep=',', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 2
#       1 # export data1_fit to csv
# ----> 2 data.to_csv('android_data/testing.csv', sep=',', index=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'android_data'
